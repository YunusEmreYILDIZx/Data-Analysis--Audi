# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
dataFrame = pd.read_excel("audi.xlsx")

# %%
dataFrame
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6
# ...     ...   ...    ...          ...      ...      ...  ...   ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9
#
#                 engineSize
# 0      2023-04-01 00:00:00
# 1                      2.0
# 2      2023-04-01 00:00:00
# 3                      2.0
# 4                      1.0
# ...                    ...
# 10663                  1.0
# 10664                  1.0
# 10665                  1.0
# 10666  2023-04-01 00:00:00
# 10667  2023-04-01 00:00:00
#
# [10668 rows x 9 columns]

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax
# count  10668.000000   10668.000000   10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436
# std        2.167494   11714.841888   23505.257205     67.170294
# min     1997.000000    1490.000000       1.000000      0.000000
# 25%     2016.000000   15130.750000    5968.750000    125.000000
# 50%     2017.000000   20200.000000   19000.000000    145.000000
# 75%     2019.000000   27990.000000   36464.500000    145.000000
# max     2020.000000  145000.000000  323000.000000    580.000000

# %%
dataFrame.isnull().sum()
# Out:
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sbn.distplot(dataFrame["price"])
# Out:
# C:\Users\emrey\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sbn.countplot(dataFrame["year"])
# Out:
# C:\Users\emrey\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
dataFrame.corr()
# Out:
#              year     price   mileage       tax
# year     1.000000  0.592581 -0.789667  0.093066
# price    0.592581  1.000000 -0.535357  0.356157
# mileage -0.789667 -0.535357  1.000000 -0.166547
# tax      0.093066  0.356157 -0.166547  1.000000

# %%
dataFrame.corr()["price"].sort_values()
# Out:
# mileage   -0.535357
# tax        0.356157
# year       0.592581
# price      1.000000
# Name: price, dtype: float64

# %%
sbn.scatterplot(x="mileage",y="price",data=dataFrame)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='price'>

# %%
dataFrame.sort_values("price",ascending = False).head(20)
# Out:
#       model  year   price transmission  mileage fuelType  tax  \
# 4783     R8  2020  145000    Semi-Auto     2000   Petrol  145
# 2255     R8  2020  137995    Semi-Auto       70   Petrol  145
# 4179     R8  2019  137500    Semi-Auto       10   Petrol  150
# 3367     R8  2019  135000    Automatic     1000   Petrol  145
# 5459     R8  2020  133900    Semi-Auto      333   Petrol  145
# 1646     R8  2019  129000    Semi-Auto     4000   Petrol  145
# 10468    R8  2019  125000    Automatic    13663   Petrol  150
# 4925     R8  2019  125000    Semi-Auto      500   Petrol  145
# 3359     R8  2019  125000    Automatic      100   Petrol  145
# 7445     R8  2019  119995    Semi-Auto     7800   Petrol  145
# 7128     R8  2019  119450    Automatic     3000   Petrol  145
# 4742     R8  2019  117990    Automatic    11936   Petrol  145
# 5707     R8  2019  116000    Automatic     2369   Petrol  145
# 3939     R8  2019  112990    Automatic     8175   Petrol  145
# 4954     R8  2019  109990    Automatic     6954   Petrol  145
# 6384    RS6  2020  109495    Semi-Auto     1500   Petrol  150
# 10225   RS6  2020  104948    Automatic     3000   Petrol  145
# 4400    RS6  2020  102544    Semi-Auto     2000   Petrol  145
# 3711    RS6  2020   97500    Semi-Auto     3220   Petrol  150
# 8630     R8  2018   95950    Automatic     5044   Petrol  150
#
#                        mpg           engineSize
# 4783   2023-01-21 00:00:00  2023-02-05 00:00:00
# 2255   2023-01-21 00:00:00  2023-02-05 00:00:00
# 4179   2023-04-21 00:00:00  2023-02-05 00:00:00
# 3367                  32.8  2023-02-05 00:00:00
# 5459   2023-04-21 00:00:00  2023-02-05 00:00:00
# 1646   2023-04-21 00:00:00  2023-02-05 00:00:00
# 10468  2023-04-21 00:00:00  2023-02-05 00:00:00
# 4925   2023-04-21 00:00:00  2023-02-05 00:00:00
# 3359   2023-01-24 00:00:00  2023-02-05 00:00:00
# 7445   2023-04-21 00:00:00  2023-02-05 00:00:00
# 7128   2023-04-21 00:00:00  2023-02-05 00:00:00
# 4742   2023-04-21 00:00:00  2023-02-05 00:00:00
# 5707   2023-06-22 00:00:00  2023-02-05 00:00:00
# 3939   2023-06-21 00:00:00  2023-02-05 00:00:00
# 4954   2023-06-21 00:00:00  2023-02-05 00:00:00
# 6384   2023-01-22 00:00:00                  4.0
# 10225  2023-01-22 00:00:00                  4.0
# 4400   2023-01-22 00:00:00                  4.0
# 3711   2023-01-22 00:00:00                  4.0
# 8630                  23.0  2023-02-05 00:00:00

# %%
dataFrame.sort_values("price",ascending = True).head(20)
# Out:
#       model  year  price transmission  mileage fuelType  tax  \
# 10588    A3  2003   1490    Automatic   101000   Diesel  240
# 10552    A4  2004   1699       Manual   110000   Diesel  315
# 7795     A3  2005   1975       Manual   104000   Petrol  240
# 10108    TT  2002   1990       Manual   131925   Petrol  325
# 7404     A3  2009   2490       Manual   152034   Diesel  150
# 9822     A6  2008   2490       Manual   323000   Diesel  200
# 10158    A2  2003   2490       Manual   100000   Diesel   30
# 9897     A3  2005   2495       Manual   122000   Diesel  150
# 9359     A6  2003   2495       Manual   129000   Diesel  325
# 7750     A6  2003   2495    Automatic   117000   Diesel  290
# 10259    A6  2007   2600       Manual   127700   Diesel  205
# 9543     A4  2007   2675       Manual   125000   Petrol  305
# 9634     A3  2007   2795       Manual   104000   Diesel  145
# 9523     TT  2002   2876       Manual    99000   Petrol  295
# 9895     TT  2004   2895       Manual   129000   Petrol  325
# 10500    A3  2005   2895       Manual   106790   Petrol  240
# 10179    A4  2005   2990       Manual    95000   Petrol  300
# 9882     A3  2007   2995       Manual   128000   Diesel  200
# 10516    A4  2006   2995       Manual   114000   Diesel  195
# 9726     A3  2008   2995       Manual   136000   Diesel  205
#
#                        mpg           engineSize
# 10588                 44.5  2023-09-01 00:00:00
# 10552                 36.2  2023-05-02 00:00:00
# 7795                  38.1                  2.0
# 10108  2023-01-30 00:00:00  2023-08-01 00:00:00
# 7404                  55.4  2023-09-01 00:00:00
# 9822                  44.1                  2.0
# 10158                 65.7  2023-04-01 00:00:00
# 9897                  53.3                  0.0
# 9359   2023-07-31 00:00:00  2023-05-02 00:00:00
# 7750                  39.8  2023-05-02 00:00:00
# 10259                 44.1                  2.0
# 9543                  34.9                  2.0
# 9634                  53.3  2023-09-01 00:00:00
# 9523   2023-01-30 00:00:00  2023-08-01 00:00:00
# 9895   2023-08-30 00:00:00  2023-08-01 00:00:00
# 10500                 35.3  2023-06-01 00:00:00
# 10179                 34.9                  2.0
# 9882                  48.7                  2.0
# 10516                 48.7                  2.0
# 9726                  48.7                  2.0

# %%
len(dataFrame)
# Out:
# 10668

# %%
len(dataFrame) * 0.01
# Out:
# 106.68

# %%
yuzdeDoksanDokuzDf = dataFrame.sort_values("price",ascending = False).iloc[131:]

# %%
yuzdeDoksanDokuzDf.describe()
# Out:
#                year         price        mileage           tax
# count  10537.000000  10537.000000   10537.000000  10537.000000
# mean    2017.075733  22242.956819   25053.583847    125.642498
# std        2.166467   9925.584942   23550.811278     67.126593
# min     1997.000000   1490.000000       5.000000      0.000000
# 25%     2016.000000  15000.000000    6000.000000    125.000000
# 50%     2017.000000  20000.000000   19349.000000    145.000000
# 75%     2019.000000  27637.000000   36790.000000    145.000000
# max     2020.000000  58495.000000  323000.000000    580.000000

# %%
plt.figure(figsize=(7,5))
sbn.distplot(yuzdeDoksanDokuzDf["price"])
# Out:
# C:\Users\emrey\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
dataFrame.describe()
# Out:
#                year          price        mileage           tax
# count  10668.000000   10668.000000   10668.000000  10668.000000
# mean    2017.100675   22896.685039   24827.244001    126.011436
# std        2.167494   11714.841888   23505.257205     67.170294
# min     1997.000000    1490.000000       1.000000      0.000000
# 25%     2016.000000   15130.750000    5968.750000    125.000000
# 50%     2017.000000   20200.000000   19000.000000    145.000000
# 75%     2019.000000   27990.000000   36464.500000    145.000000
# max     2020.000000  145000.000000  323000.000000    580.000000

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13890.659955
# 2015    15128.235235
# 2016    16908.725051
# 2017    19951.624289
# 2018    26296.707176
# 2019    30410.752268
# 2020    35967.067039
# Name: price, dtype: float64

# %%
yuzdeDoksanDokuzDf.groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13787.298206
# 2015    15128.235235
# 2016    16847.266055
# 2017    19867.091144
# 2018    25344.289941
# 2019    29585.353372
# 2020    32881.481928
# Name: price, dtype: float64

# %%
dataFrame[dataFrame.year != 1970].groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13890.659955
# 2015    15128.235235
# 2016    16908.725051
# 2017    19951.624289
# 2018    26296.707176
# 2019    30410.752268
# 2020    35967.067039
# Name: price, dtype: float64

# %%
dataFrame = yuzdeDoksanDokuzDf

# %%
dataFrame.describe()
# Out:
#                year         price        mileage           tax
# count  10537.000000  10537.000000   10537.000000  10537.000000
# mean    2017.075733  22242.956819   25053.583847    125.642498
# std        2.166467   9925.584942   23550.811278     67.126593
# min     1997.000000   1490.000000       5.000000      0.000000
# 25%     2016.000000  15000.000000    6000.000000    125.000000
# 50%     2017.000000  20000.000000   19349.000000    145.000000
# 75%     2019.000000  27637.000000   36790.000000    145.000000
# max     2020.000000  58495.000000  323000.000000    580.000000

# %%
dataFrame = dataFrame[dataFrame.year != 1970]

# %%
dataFrame.groupby("year").mean()["price"]
# Out:
# year
# 1997     4650.000000
# 1998     4999.000000
# 2002     2433.000000
# 2003     3408.333333
# 2004     5053.600000
# 2005     3490.714286
# 2006     6499.111111
# 2007     7325.250000
# 2008     6281.428571
# 2009     6281.956522
# 2010     7224.093750
# 2011     8944.808511
# 2012     9860.811765
# 2013    11690.790378
# 2014    13787.298206
# 2015    15128.235235
# 2016    16847.266055
# 2017    19867.091144
# 2018    25344.289941
# 2019    29585.353372
# 2020    32881.481928
# Name: price, dtype: float64

# %%
dataFrame.head()
# Out:
#      model  year  price transmission  mileage fuelType  tax  \
# 2254    Q5  2020  58495    Semi-Auto     4000   Diesel  145
# 6254    Q8  2019  58450    Semi-Auto     8450   Diesel  145
# 6606    Q8  2019  58450    Automatic     7000   Diesel  145
# 7689    R8  2014  58450    Automatic    35000   Petrol  570
# 4734    Q7  2019  58216    Automatic     3052   Diesel  145
#
#                       mpg           engineSize
# 2254                 32.5                  3.0
# 6254                 33.6                  3.0
# 6606                 33.6                  3.0
# 7689  2023-09-21 00:00:00  2023-02-05 00:00:00
# 4734                 33.2                  3.0
